# %% [markdown]
# **IMPORT LIBRARIES**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **IMPORT DATASET**

# %%
df=pd.read_csv('https://github.com/YBI-Foundation/Dataset/raw/main/MPG.csv')

# %%
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
df.nunique()
# Out:
# mpg             129
# cylinders         5
# displacement     82
# horsepower       93
# weight          351
# acceleration     95
# model_year       13
# origin            3
# name            305
# dtype: int64

# %% [markdown]
# **DATA PREPROCESSING**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    object
#  8   name          398 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 28.1+ KB

# %%
df.describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  398.000000  398.000000    398.000000  392.000000   398.000000
# mean    23.514573    5.454774    193.425879  104.469388  2970.424623
# std      7.815984    1.701004    104.269838   38.491160   846.841774
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.500000    4.000000    104.250000   75.000000  2223.750000
# 50%     23.000000    4.000000    148.500000   93.500000  2803.500000
# 75%     29.000000    8.000000    262.000000  126.000000  3608.000000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration  model_year
# count    398.000000  398.000000
# mean      15.568090   76.010050
# std        2.757689    3.697627
# min        8.000000   70.000000
# 25%       13.825000   73.000000
# 50%       15.500000   76.000000
# 75%       17.175000   79.000000
# max       24.800000   82.000000

# %%
df.corr()
# Out:
# <ipython-input-7-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                    mpg  cylinders  displacement  horsepower    weight  \
# mpg           1.000000  -0.775396     -0.804203   -0.778427 -0.831741
# cylinders    -0.775396   1.000000      0.950721    0.842983  0.896017
# displacement -0.804203   0.950721      1.000000    0.897257  0.932824
# horsepower   -0.778427   0.842983      0.897257    1.000000  0.864538
# weight       -0.831741   0.896017      0.932824    0.864538  1.000000
# acceleration  0.420289  -0.505419     -0.543684   -0.689196 -0.417457
# model_year    0.579267  -0.348746     -0.370164   -0.416361 -0.306564
#
#               acceleration  model_year
# mpg               0.420289    0.579267
# cylinders        -0.505419   -0.348746
# ...

# %% [markdown]
# **REMOVING MISSING VALUES**

# %%
df=df.dropna()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 392 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           392 non-null    float64
#  1   cylinders     392 non-null    int64
#  2   displacement  392 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        392 non-null    int64
#  5   acceleration  392 non-null    float64
#  6   model_year    392 non-null    int64
#  7   origin        392 non-null    object
#  8   name          392 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 30.6+ KB

# %% [markdown]
# **DATA VISUALIZATION**

# %%
sns.pairplot(df,x_vars=['displacement','horsepower','weight','acceleration','mpg'],y_vars=['mpg'])

# %%
sns.regplot(x='displacement',y='mpg',data=df)
# Out:
# <Axes: xlabel='displacement', ylabel='mpg'>

# %%
sns.regplot(x='cylinders',y='mpg',data=df)
# Out:
# <Axes: xlabel='cylinders', ylabel='mpg'>

# %%
sns.regplot(x='horsepower',y='mpg',data=df)
# Out:
# <Axes: xlabel='horsepower', ylabel='mpg'>

# %%
sns.regplot(x='weight',y='mpg',data=df)
# Out:
# <Axes: xlabel='weight', ylabel='mpg'>

# %%
sns.regplot(x='acceleration',y='mpg',data=df)
# Out:
# <Axes: xlabel='acceleration', ylabel='mpg'>

# %%
sns.regplot(x='model_year',y='mpg',data=df)
# Out:
# <Axes: xlabel='model_year', ylabel='mpg'>

# %% [markdown]
# **Define Target y variable and X feature variable**

# %%
df.columns
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model_year', 'origin', 'name'],
#       dtype='object')

# %%
y=df['mpg']

# %%
y.shape
# Out:
# (392,)

# %%
X=df[['displacement', 'horsepower', 'weight','acceleration']]

# %%
X.shape
# Out:
# (392, 4)

# %% [markdown]
# **SCALING DATA**

# %%
from sklearn.preprocessing import StandardScaler

# %%
ss=StandardScaler()

# %%
X=ss.fit_transform(X)

# %%
X
# Out:
# array([[ 1.07728956,  0.66413273,  0.62054034, -1.285258  ],
#        [ 1.48873169,  1.57459447,  0.84333403, -1.46672362],
#        [ 1.1825422 ,  1.18439658,  0.54038176, -1.64818924],
#        ...,
#        [-0.56847897, -0.53247413, -0.80463202, -1.4304305 ],
#        [-0.7120053 , -0.66254009, -0.41562716,  1.11008813],
#        [-0.72157372, -0.58450051, -0.30364091,  1.40043312]])

# %%
pd.DataFrame(X).describe()
# Out:
#                   0             1             2             3
# count  3.920000e+02  3.920000e+02  3.920000e+02  3.920000e+02
# mean  -7.250436e-17 -1.812609e-16 -1.812609e-17  4.350262e-16
# std    1.001278e+00  1.001278e+00  1.001278e+00  1.001278e+00
# min   -1.209563e+00 -1.520975e+00 -1.608575e+00 -2.736983e+00
# 25%   -8.555316e-01 -7.665929e-01 -8.868535e-01 -6.410551e-01
# 50%   -4.153842e-01 -2.853488e-01 -2.052109e-01 -1.499869e-02
# 75%    7.782764e-01  5.600800e-01  7.510927e-01  5.384714e-01
# max    2.493416e+00  3.265452e+00  2.549061e+00  3.360262e+00

# %% [markdown]
# **Train Test Split Data**

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,train_size=0.7,random_state=2529)

# %%
X_train.shape,X_test.shape,y_train.shape,y_test.shape
# Out:
# ((274, 4), (118, 4), (274,), (118,))

# %% [markdown]
# **Linear Regression Model**

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
lr.intercept_
# Out:
# 23.485738559737584

# %%
lr.coef_
# Out:
# array([-1.05767743, -1.68734727, -4.10787617, -0.11495177])

# %% [markdown]
# **Mileage=23.4 Displacement-1.05 Horsepower-1.68 Weight-4.10 Acceleration-0.114 + error**

# %% [markdown]
# **Predict Test Data**

# %%
y_pred=lr.predict(X_test)

# %%
y_pred
# Out:
# array([18.51865637, 15.09305675, 14.30128789, 23.6753321 , 29.7546115 ,
#        23.68796629, 26.61066644, 24.56692437, 15.06260986, 11.94312046,
#        24.08050053, 27.96518468, 31.66130278, 31.01309132, 18.32428976,
#        19.32795009, 28.08847536, 32.1506879 , 31.15859692, 27.15792144,
#        18.82433097, 22.54580176, 26.15598115, 32.36393869, 20.74377679,
#         8.78027518, 22.19699435, 18.20614294, 25.00052718, 15.26421552,
#        23.13441082, 17.10542257,  9.87180062, 30.00790415, 20.41204655,
#        29.11860245, 24.4305187 , 21.72601835, 10.51174626, 13.12426391,
#        21.41938406, 19.96113872,  6.19146626, 17.79025345, 22.5493033 ,
#        29.34765021, 13.4861847 , 25.88852083, 29.40406946, 22.41841964,
#        22.07684766, 16.46575802, 24.06290693, 30.12890046, 10.11318121,
#         9.85011438, 28.07543852, 23.41426617, 20.08501128, 30.68234133,
#        20.92026393, 26.78370281, 22.9078744 , 14.15936872, 24.6439883 ,
# ...

# %% [markdown]
# **Model Accuracy**

# %%
from sklearn.metrics import mean_absolute_error,mean_absolute_percentage_error,r2_score

# %%
mean_absolute_error(y_test,y_pred)
# Out:
# 3.3286968643244106

# %%
mean_absolute_percentage_error(y_test,y_pred)
# Out:
# 0.14713035779536746

# %%
r2_score(y_test,y_pred)
# Out:
# 0.7031250746717691

# %%
#X=df[['displacement', 'horsepower', 'weight','acceleration']]
temp=df["displacement"].tolist()
x=[]
x=temp[:100]

temp=df["mpg"].tolist()
y=[]
y=temp[:100]

# %%
plt.scatter(x, y)
plt.plot(X_train,23.485738559737584*X_train-0.114  )
plt.title('BEST FIT line')
plt.xlabel('diplacement')
plt.ylabel('mpg')
plt.xlim(10, 500)
plt.ylim(10, 500)

plt.show()

# %% [markdown]
# # **Polynomial Regression**

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
poly=PolynomialFeatures(degree=2,interaction_only=True,include_bias=False)

# %%
X_train2=poly.fit_transform(X_train)

# %%
X_test2=poly.fit_transform(X_test)

# %%
lr.fit(X_train2,y_train)
# Out:
# LinearRegression()

# %%
lr.intercept_
# Out:
# 21.27336450063766

# %%
lr.coef_
# Out:
# array([-2.76070596, -5.00559628, -1.36884133, -0.81225214,  1.24596571,
#        -0.12475017, -0.90542822,  1.35064048, -0.17337823,  1.41680398])

# %%
y_pred_poly=lr.predict(X_test2)

# %% [markdown]
# **Model Accuracy**

# %%
from sklearn.metrics import mean_absolute_error,mean_absolute_percentage_error,r2_score

# %%
mean_absolute_error(y_test,y_pred_poly)
# Out:
# 2.7887147720295977

# %%
mean_absolute_percentage_error(y_test,y_pred_poly)
# Out:
# 0.12074018342938687

# %%
r2_score(y_test,y_pred_poly)
# Out:
# 0.7461731314563803

# %%
print(list(y_test))
m=list(y_test)
m=m[:10]
# Out:
# [19.2, 15.5, 14.0, 28.1, 26.0, 20.2, 24.0, 22.0, 13.0, 14.0, 27.2, 30.0, 29.5, 31.0, 16.0, 16.0, 21.0, 36.1, 29.0, 29.0, 18.0, 19.4, 21.0, 26.0, 22.4, 14.0, 17.0, 18.0, 23.0, 14.0, 22.5, 19.4, 9.0, 28.0, 18.5, 32.2, 19.0, 19.1, 16.0, 13.0, 17.0, 18.1, 12.0, 17.6, 19.0, 30.9, 13.0, 24.0, 27.0, 18.0, 19.0, 23.0, 18.0, 32.1, 13.0, 16.0, 22.0, 38.0, 18.1, 34.4, 16.0, 21.1, 18.0, 14.0, 21.6, 24.0, 18.5, 19.8, 31.8, 14.0, 22.0, 18.0, 13.0, 37.3, 30.0, 27.2, 34.1, 11.0, 22.0, 15.0, 27.0, 28.0, 15.5, 35.0, 39.4, 31.0, 15.0, 31.0, 33.5, 32.4, 35.1, 36.0, 32.8, 43.1, 20.0, 32.0, 21.0, 36.0, 32.0, 23.5, 17.0, 19.0, 32.7, 22.0, 15.0, 21.0, 24.0, 10.0, 21.5, 37.7, 25.4, 13.0, 40.8, 23.0, 34.0, 26.0, 16.2, 24.0]

# %%
print(list(y_pred))
n=list(y_pred)
n=n[:10]
# Out:
# [18.51865636526067, 15.093056747863898, 14.301287890482213, 23.67533210226238, 29.754611498480067, 23.687966289117046, 26.61066644006708, 24.56692437054814, 15.062609860251099, 11.943120462363487, 24.080500526959494, 27.965184682573433, 31.66130278317864, 31.01309131971893, 18.32428975711887, 19.32795009045725, 28.08847535536222, 32.150687899040996, 31.158596922143303, 27.15792143773889, 18.824330970039732, 22.545801761993058, 26.155981153127577, 32.36393868965361, 20.743776790738096, 8.780275183103672, 22.196994354955546, 18.20614293743897, 25.000527178657144, 15.264215515854485, 23.13441082114688, 17.105422567931704, 9.871800624773435, 30.007904151071, 20.41204654777965, 29.118602452485234, 24.430518696301405, 21.726018353663363, 10.511746263834533, 13.124263909860757, 21.41938405740202, 19.961138723885536, 6.191466263391845, 17.790253445089306, 22.5493033044581, 29.34765020545189, 13.486184703050686, 25.88852083430398, 29.404069463977248, 22.418419644266713, 22.07684766143818, 16.
# ...

# %%
plt.plot(m,n)
plt.xlabel('y_test')
plt.ylabel('y_pred')
plt.show()

# %% [markdown]
# # **Random Forest**

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf = RandomForestRegressor(n_estimators = 300)
rf.fit(X_train,y_train)
y_pred = rf.predict(X_test)

# %% [markdown]
# **Model Accuracy**

# %%
from sklearn.metrics import mean_absolute_error,mean_absolute_percentage_error,r2_score

# %%
mean_absolute_error(y_test,y_pred)
# Out:
# 2.668211259079906

# %%
r2_score(y_test,y_pred)
# Out:
# 0.7720287797873999

# %%
print(list(y_test))
m=list(y_test)
m=m[:10]
print(list(y_pred))
n=list(y_pred)
n=n[:10]
plt.plot(m,n)
plt.xlabel('y_test')
plt.ylabel('y_pred')
plt.show()
# Out:
# [19.2, 15.5, 14.0, 28.1, 26.0, 20.2, 24.0, 22.0, 13.0, 14.0, 27.2, 30.0, 29.5, 31.0, 16.0, 16.0, 21.0, 36.1, 29.0, 29.0, 18.0, 19.4, 21.0, 26.0, 22.4, 14.0, 17.0, 18.0, 23.0, 14.0, 22.5, 19.4, 9.0, 28.0, 18.5, 32.2, 19.0, 19.1, 16.0, 13.0, 17.0, 18.1, 12.0, 17.6, 19.0, 30.9, 13.0, 24.0, 27.0, 18.0, 19.0, 23.0, 18.0, 32.1, 13.0, 16.0, 22.0, 38.0, 18.1, 34.4, 16.0, 21.1, 18.0, 14.0, 21.6, 24.0, 18.5, 19.8, 31.8, 14.0, 22.0, 18.0, 13.0, 37.3, 30.0, 27.2, 34.1, 11.0, 22.0, 15.0, 27.0, 28.0, 15.5, 35.0, 39.4, 31.0, 15.0, 31.0, 33.5, 32.4, 35.1, 36.0, 32.8, 43.1, 20.0, 32.0, 21.0, 36.0, 32.0, 23.5, 17.0, 19.0, 32.7, 22.0, 15.0, 21.0, 24.0, 10.0, 21.5, 37.7, 25.4, 13.0, 40.8, 23.0, 34.0, 26.0, 16.2, 24.0]
# ...

# %% [markdown]
# # **Decision Tree**

# %%
import numpy as np
from sklearn.tree import DecisionTreeRegressor
rng = np.random.RandomState(1)
# Fit regression model
regr = DecisionTreeRegressor(max_depth=2)
regr.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor(max_depth=2)

# %%
y_pred=regr.predict(X_test)

# %% [markdown]
# **Model**

# %%
from sklearn.metrics import mean_absolute_error,mean_absolute_percentage_error,r2_score

# %%
mean_absolute_error(y_test,y_pred)
# Out:
# 3.3053849562423827

# %%
r2_score(y_test,y_pred)
# Out:
# 0.6655881058508303

# %%
print(list(y_test))
m=list(y_test)
m=m[:100:10]
print(list(y_pred))
n=list(y_pred)
n=n[:100:10]
plt.plot(m,n)
plt.xlabel('y_test')
plt.ylabel('y_pred')
plt.show()
# Out:
# [19.2, 15.5, 14.0, 28.1, 26.0, 20.2, 24.0, 22.0, 13.0, 14.0, 27.2, 30.0, 29.5, 31.0, 16.0, 16.0, 21.0, 36.1, 29.0, 29.0, 18.0, 19.4, 21.0, 26.0, 22.4, 14.0, 17.0, 18.0, 23.0, 14.0, 22.5, 19.4, 9.0, 28.0, 18.5, 32.2, 19.0, 19.1, 16.0, 13.0, 17.0, 18.1, 12.0, 17.6, 19.0, 30.9, 13.0, 24.0, 27.0, 18.0, 19.0, 23.0, 18.0, 32.1, 13.0, 16.0, 22.0, 38.0, 18.1, 34.4, 16.0, 21.1, 18.0, 14.0, 21.6, 24.0, 18.5, 19.8, 31.8, 14.0, 22.0, 18.0, 13.0, 37.3, 30.0, 27.2, 34.1, 11.0, 22.0, 15.0, 27.0, 28.0, 15.5, 35.0, 39.4, 31.0, 15.0, 31.0, 33.5, 32.4, 35.1, 36.0, 32.8, 43.1, 20.0, 32.0, 21.0, 36.0, 32.0, 23.5, 17.0, 19.0, 32.7, 22.0, 15.0, 21.0, 24.0, 10.0, 21.5, 37.7, 25.4, 13.0, 40.8, 23.0, 34.0, 26.0, 16.2, 24.0]
# ...

# %% [markdown]
# # **Logistic Regression**

# %%
df.columns
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model_year', 'origin', 'name'],
#       dtype='object')

# %%
y1=df['cylinders']

# %%
X1=df[['displacement', 'horsepower', 'weight','acceleration']]

# %%
X_train,X_test,y_train,y_test=train_test_split(X1,y1,train_size=0.7,random_state=2529)

# %%
from sklearn.linear_model import LogisticRegression
modelLogistic = LogisticRegression()
modelLogistic.fit(X_train,y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_pred= modelLogistic.predict(X_test)

# %% [markdown]
# **Model**

# %%
mean_absolute_error(y_test,y_pred)
# Out:
# 0.22033898305084745

# %%
r2_score(y_test,y_pred)
# Out:
# 0.8549941014549745

# %%
print(list(y_test))
m=list(y_test)
m=m[:10]
print(list(y_pred))
n=list(y_pred)
n=n[:10]
plt.plot(m,n)
plt.xlabel('y_test')
plt.ylabel('y_pred')
plt.show()
# Out:
# [8, 8, 8, 4, 4, 6, 4, 6, 8, 8, 4, 4, 4, 4, 6, 6, 4, 4, 4, 4, 8, 6, 6, 4, 6, 8, 6, 8, 4, 8, 6, 8, 8, 4, 6, 4, 4, 6, 8, 8, 6, 8, 8, 8, 6, 4, 8, 4, 4, 6, 6, 8, 6, 4, 8, 8, 4, 6, 6, 4, 6, 4, 6, 8, 4, 4, 8, 6, 4, 8, 4, 6, 8, 4, 4, 4, 4, 8, 4, 8, 4, 4, 8, 4, 4, 4, 8, 4, 4, 4, 4, 4, 4, 4, 8, 4, 6, 4, 4, 6, 8, 4, 6, 6, 8, 4, 4, 8, 3, 4, 5, 8, 4, 4, 4, 4, 6, 4]
# [8, 8, 8, 4, 4, 6, 4, 6, 8, 8, 4, 4, 4, 4, 6, 6, 4, 4, 4, 4, 8, 6, 6, 4, 6, 8, 4, 8, 4, 8, 6, 8, 6, 4, 6, 4, 4, 6, 8, 8, 8, 8, 8, 8, 6, 4, 8, 4, 4, 6, 8, 8, 6, 4, 8, 8, 4, 8, 6, 4, 6, 4, 8, 8, 4, 4, 8, 6, 4, 8, 4, 6, 8, 4, 4, 4, 4, 6, 4, 8, 4, 4, 8, 4, 4, 4, 8, 4, 6, 4, 4, 4, 4, 4, 8, 4, 4, 4, 4, 6, 8, 5, 4, 6, 8, 4, 4, 6, 3, 4, 6, 8, 4, 4, 4, 4, 4, 4]

# %%
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
X=df[['displacement', 'horsepower', 'weight','acceleration']]
y=df['mpg']

# %%
import seaborn as sns
from sklearn import preprocessing
from sklearn.preprocessing import LabelEncoder

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X)
PCA_df = pd.DataFrame(data = X_pca, columns = ['PC1', 'PC2'])
PCA_df = pd.concat([PCA_df, df['mpg']], axis = 1)
PCA_df['mpg'] = LabelEncoder().fit_transform(PCA_df['mpg'])
PCA_df.head()
# Out:
#           PC1        PC2  mpg
# 0  536.433503  50.707007   17
# 1  730.330486  79.027737    7
# 2  470.969981  75.324297   17
# 3  466.389820  62.404940    9
# 4  481.656312  55.650979   13

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

# %%
figure(num=None, figsize=(8, 8), dpi=80, facecolor='w', edgecolor='k')

classes = [1, 0]
colors = ['r', 'b']
for clas, color in zip(classes, colors):
    plt.scatter(PCA_df.loc[PCA_df['mpg'] == clas, 'PC1'], 
                PCA_df.loc[PCA_df['mpg'] == clas, 'PC2'], 
                c = color)
    
plt.xlabel('Principal Component 1', fontsize = 12)
plt.ylabel('Principal Component 2', fontsize = 12)
plt.title('2D PCA', fontsize = 15)
plt.legend(['Poisonous', 'Edible'])
plt.grid()
